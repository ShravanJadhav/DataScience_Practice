# %% [markdown]
# ###DAY16

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/dataset 1.csv')

# %%
df.head()
# Out:
#   Policy no.  age     sex     bmi  charges in INR
# 0  PLC156898   19  female  27.900     16884.92400
# 1  PLC156907   18    male  33.770      1725.55230
# 2  PLC156916   28    male  33.000      4449.46200
# 3  PLC156925   33    male  22.705     21984.47061
# 4  PLC156934   32    male  28.880      3866.85520

# %%
fig = plt.figure(figsize=(15,6))
ax = fig.add_subplot(2,2,1)
sns.distplot(df['age'], color='r').set_title('Age')

ax = fig.add_subplot(2,2,2)
sns.distplot(df['bmi'], color='black').set_title('BMI')

ax = fig.add_subplot(2,2,3)
sns.distplot(df['charges in INR'],color='g').set_title('Charges in INR')

ax = fig.add_subplot(2,2,4)
sns.countplot(df['sex'],color='b').set_title('SEX')

plt.show()

# %%
df.head()
# Out:
#   Policy no.  age     sex     bmi  charges in INR
# 0  PLC156898   19  female  27.900     16884.92400
# 1  PLC156907   18    male  33.770      1725.55230
# 2  PLC156916   28    male  33.000      4449.46200
# 3  PLC156925   33    male  22.705     21984.47061
# 4  PLC156934   32    male  28.880      3866.85520

# %%
fig = plt.figure(figsize=(25,40))
ax  = plt.subplot(3,2,1)
sns.histplot(df['age']).set_title('Age Histo')
ax  = plt.subplot(3,2,2)
sns.boxplot(df['age']).set_title('Age Outlier')

ax  = plt.subplot(3,2,3)
sns.histplot(df['bmi']).set_title('bmi Histo')
ax  = plt.subplot(3,2,4)
sns.boxplot(df['bmi']).set_title('bmi Outlier')

ax  = plt.subplot(3,2,5)
sns.histplot(df['charges in INR']).set_title('charges in INR Histo')
ax  = plt.subplot(3,2,6)
sns.boxplot(df['charges in INR'])



plt.show()

# %% [markdown]
# Detecting Outlier records in the dataset

# %%
df.head()
# Out:
#   Policy no.  age     sex     bmi  charges in INR
# 0  PLC156898   19  female  27.900     16884.92400
# 1  PLC156907   18    male  33.770      1725.55230
# 2  PLC156916   28    male  33.000      4449.46200
# 3  PLC156925   33    male  22.705     21984.47061
# 4  PLC156934   32    male  28.880      3866.85520

# %%
df.describe()
# Out:
#                age          bmi  charges in INR
# count  1339.000000  1338.000000     1339.000000
# mean     39.204630    30.663397    13284.666580
# std      14.044982     6.098187    12116.701295
# min      18.000000    15.960000     1121.873900
# 25%      27.000000    26.296250     4742.306100
# 50%      39.000000    30.400000     9386.161300
# 75%      51.000000    34.693750    16717.010750
# max      64.000000    53.130000    63770.428010

# %%
#bmi outlier
Q1 = 26.296250
Q3 = 34.693750
IQR =  Q3-Q1
print(IQR)
# Out:
# 8.3975

# %%
a = Q1-1.5*(IQR)
b = Q3+1.5*(IQR)

print(a)
print(b)
# Out:
# 13.7
# 47.290000000000006

# %%
#above 47.29 and below 13.7 bmi are outliers

# %%
col = 'bmi'
Q1 = df['bmi'].quantile(0.25)
Q2 = df['bmi'].quantile(0.75)
IQR = Q3-Q1
display((df.loc[(df[col]<(Q1-1.5*IQR) )| (df[col]>(Q3+1.5*IQR))]))
fig = plt.figure(figsize=(10,6))
sns.boxplot(df['bmi'])
plt.show()
# Out:
#      Policy no.  age     sex    bmi  charges in INR
# 116   PLC157942   58    male  49.06     11381.32540
# 286   PLC159472   46  female  48.07      9432.92530
# 401   PLC160507   47    male  47.52      8083.91980
# 543   PLC161785   54  female  47.41     63770.42801
# 847   PLC164521   23    male  50.38      2438.05520
# 860   PLC164638   37  female  47.60     46113.51100
# 1047  PLC166321   22    male  52.58     44501.39820
# 1088  PLC166690   52    male  47.74      9748.91060
# 1317  PLC168751   18    male  53.13      1163.46270
